# %% [markdown]
# # Check GPU availability

# %%
# !nvidia-smi
# Out:
# Mon Mar 25 07:13:33 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# # Install WhisperX

# %%
! pip install git+https://github.com/m-bain/whisperx.git
# Out:
# ...
#   Cloning https://github.com/m-bain/whisperx.git to /tmp/pip-req-build-sn4b6ouw
#   Running command git clone --filter=blob:none --quiet https://github.com/m-bain/whisperx.git /tmp/pip-req-build-sn4b6ouw
#   Resolved https://github.com/m-bain/whisperx.git to commit f2da2f858e99e4211fe4f64b5f2938b007827e17
#   Preparing metadata (setup.py) ... done
# ...

# %% [markdown]
# # Install Whisper

# %%
! pip install git+https://github.com/openai/whisper.git
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-7wtp6oaz
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-7wtp6oaz
#   Resolved https://github.com/openai/whisper.git to commit ba3f3cd54b0e5b8ce1ab3de13e32122d0d5f98ab
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 14.0 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20231117-py3-none-any.whl size=802826 sha256=3a1d39fec9400dcbc6faf91593ab5a011f62a53a45131c5069bcebdb1d654c36
#   Stored in directory: /tmp/pip-ephem-wheel-cache-n5a_dupa/wheels/8b/6c/d0/622666868c179f156cf595c8b6f06f88bc5d80c4b31dccaa03
# Successfully built openai-whisper
# ...

# %% [markdown]
# # Upload Input Audio / Video File

# %%
! ffmpeg
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# !whisperx /content/Thirumalai Road.wav
# Out:
# 2024-03-25 07:04:20.406080: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-25 07:04:20.406184: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-25 07:04:20.579098: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-25 07:04:23.370175: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/pyannote/audio/core/io.py:43: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
# ...

# %%
# !whisperx /content/HDFCsmall2ppl.wav --model large-v2 --diarize --highlight_words True --min_speakers 2 --max_speakers 2
# Out:
# 2024-03-15 10:58:50.013713: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-15 10:58:50.013767: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-15 10:58:50.015191: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-15 10:58:51.276732: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/pyannote/audio/core/io.py:43: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
# ...

# %%
import whisperx
import gc
# Out:
# /usr/local/lib/python3.10/dist-packages/pyannote/audio/core/io.py:43: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")

# %%
device='cuda'
audio_file = "/content/Thirumalai Road.wav"
batch_size = 16 # reduce if low on GPU mem
compute_type = "float16" # change to "int8" if low on GPU mem (may reduce accuracy)

# %%
# 1. Transcribe with original whisper (batched)
model = whisperx.load_model("large-v2", device="cuda" ,  compute_type=compute_type)

# save model to local path (optional)
# model_dir = "/path/"
# model = whisperx.load_model("large-v2", device, compute_type=compute_type, download_root=model_dir)
# Out:
# vocabulary.txt:   0%|          | 0.00/460k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.20M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/2.80k [00:00<?, ?B/s]
# model.bin:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# No language specified, language will be first be detected for each audio file (increases inference time).
# 100%|█████████████████████████████████████| 16.9M/16.9M [00:01<00:00, 10.1MiB/s]
# INFO:pytorch_lightning.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.2.1. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../root/.cache/torch/whisperx-vad-segmentation.bin`
# Model was trained with pyannote.audio 0.0.1, yours is 3.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.2.1+cu121. Bad things might happen unless you revert torch to 1.x.

# %%
audio = whisperx.load_audio(audio_file)
result = model.transcribe(audio, batch_size=batch_size, language='en')
print(result["segments"]) # before alignment

# delete model if low on GPU resources
# import gc; gc.collect(); torch.cuda.empty_cache(); del model
# Out:
# [{'text': " Come on Ravind, your product, you start. Okay, fine. Let's go with the demo.", 'start': 0.503, 'end': 7.398}]

# %%
# 2. Align whisper output
model_a, metadata = whisperx.load_align_model(language_code=result["language"], device=device)
result = whisperx.align(result["segments"], model_a, metadata, audio, device, return_char_alignments=False)

print(result["segments"]) # after alignment

# delete model if low on GPU resources
# import gc; gc.collect(); torch.cuda.empty_cache(); del model_a
# Out:
# [{'start': 0.824, 'end': 5.013, 'text': ' Come on Ravind, your product, you start.', 'words': [{'word': 'Come', 'start': 0.824, 'end': 2.227, 'score': 0.791}, {'word': 'on', 'start': 2.267, 'end': 2.347, 'score': 0.509}, {'word': 'Ravind,', 'start': 2.427, 'end': 2.688, 'score': 0.553}, {'word': 'your', 'start': 2.888, 'end': 3.129, 'score': 0.846}, {'word': 'product,', 'start': 3.75, 'end': 4.111, 'score': 0.848}, {'word': 'you', 'start': 4.572, 'end': 4.732, 'score': 0.774}, {'word': 'start.', 'start': 4.752, 'end': 5.013, 'score': 0.792}]}, {'start': 5.714, 'end': 6.215, 'text': 'Okay, fine.', 'words': [{'word': 'Okay,', 'start': 5.714, 'end': 5.875, 'score': 0.472}, {'word': 'fine.', 'start': 6.015, 'end': 6.215, 'score': 0.544}]}, {'start': 6.416, 'end': 7.157, 'text': "Let's go with the demo.", 'words': [{'word': "Let's", 'start': 6.416, 'end': 6.576, 'score': 0.877}, {'word': 'go', 'start': 6.616, 'end': 6.717, 'score': 0.758}, {'word': 'with', 'start': 6.777, 'end': 6.897, 's
# ...

# %%
# 3. Assign speaker labels
diarize_model = whisperx.DiarizationPipeline(use_auth_token="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", device=device)
# Out:
# config.yaml:   0%|          | 0.00/469 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/5.91M [00:00<?, ?B/s]
# config.yaml:   0%|          | 0.00/399 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/26.6M [00:00<?, ?B/s]
# config.yaml:   0%|          | 0.00/221 [00:00<?, ?B/s]

# %%
# add min/max number of speakers if known
diarize_segments = diarize_model(audio, min_speakers=1, max_speakers=3)

result = whisperx.assign_word_speakers(diarize_segments, result)
print(diarize_segments)
print(result["segments"]) # segments are now assigned speaker IDs
# Out:
#                              segment label     speaker     start       end  \
# 0  [ 00:00:00.500 -->  00:00:01.502]     A  SPEAKER_01  0.500849  1.502547
# 1  [ 00:00:02.028 -->  00:00:05.118]     B  SPEAKER_00  2.028862  5.118846
# 2  [ 00:00:05.577 -->  00:00:07.308]     C  SPEAKER_01  5.577250  7.308998
#
#    intersection     union
# 0     -5.514453  6.656151
# 1     -1.898154  5.128138
# 2      0.140000  1.731749
# ...

# %%
x=result.keys()
print(x)
# Out:
# dict_keys(['segments', 'word_segments'])

# %%
len(result['segments'])
# Out:
# 3

# %%
for i in range(len(result['segments'])):
  print(result['segments'][i]['words'][0]['speaker'], " : " , result['segments'][i]['text'] )
# Out:
# SPEAKER_01  :   Come on Ravind, your product, you start.
# SPEAKER_01  :  Okay, fine.
# SPEAKER_01  :  Let's go with the demo.

# %% [markdown]
# # Get Ass Subtitle File Saved using WhisperX

# %%
# !whisperx new_video.mp4 --model medium.en --output_dir . --align_model WAV2VEC2_ASR_LARGE_LV60K_960H --align_extend 2
# Out:
# tcmalloc: large alloc 1528012800 bytes == 0xbe32000 @  0x7f7f78f1b1e7 0x4d30a0 0x5dede2 0x61033f 0x5aab9b 0x47c416 0x6170f1 0x4f7916 0x4997a2 0x5d8868 0x4990ca 0x55cd91 0x5d8941 0x49abe4 0x5d8868 0x4990ca 0x55cd91 0x55d743 0x642630 0x6426ae 0x644b78 0x64511c 0x677e5e 0x678029 0x7f7f78b18c87 0x5e1baa
# [00:00.000 --> 00:02.080]  What do you think happens when we die Keanu Reeves?
# [00:02.080 --> 00:09.360]  I know that the ones who love us will miss us.
# Performing alignment...
# [00:00.161 --> 00:02.090]  What do you think happens when we die Keanu Reeves?
# [00:06.735 --> 00:09.458]  I know that the ones who love us will miss us.

# %% [markdown]
# # Burn the Ass Subtitle file to the Video

# %%
# !ffmpeg -i new_video.mp4 -vf "ass=new_video.mp4.ass" new_video_out.avi
# Out:
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...
